# %% [markdown]
# # P2 - Data Analyst
#
# ## Introduction
# The idea here is to explore the data and look for some conclusions we can get from the data. At this moment no question can be formulated without a first knowledge of the data

# %% [markdown]
# ## Importing
# Import libraries and CSV. Verify if CSV was imported correctly.

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from bokeh.plotting import figure
from bokeh.charts import Histogram
from bokeh.charts import Donut
from bokeh.io import output_notebook, show
from bokeh.layouts import row
import random
from sets import Set

output_notebook()

df = pd.read_csv('titanic_data.csv')
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:13: DeprecationWarning: the sets module is deprecated
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5d781da1-c621-4441-8319-cdae88b9bfcb">Loading BokehJS ...</span>
#     </div>

# %%
df.describe()
# Out:
# C:\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male   NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500          NaN        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500          NaN        S
# 5        0            330877    8.4583          NaN        Q
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750          NaN        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500          NaN        S
# 13       5            347082   31.2750          NaN        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 16       1            382652   29.1250          NaN        Q
# 17       0            244373   13.0000          NaN        S
# 18       0            345763   18.0000          NaN        S
# 19       0              2649    7.2250          NaN        C
# 20       0            239865   26.0000          NaN        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292          NaN        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 26       0              2631    7.2250          NaN        C
# 27       2             19950  263.0000  C23 C25 C27        S
# 28       0            330959    7.8792          NaN        Q
# 29       0            349216    7.8958          NaN        S
# ..     ...               ...       ...          ...      ...
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000          NaN        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 878      0            349217    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Data Cleaning
# The 'Age' has some NaN and we must fix it.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# From a total of 891 passengers, we don't have the Age of 177, the Cabin of 687 and the Place of Embark for 2.
#
# We can consider that Cabin is nearly useless and remove this column.
#
# For the Place of Embark and Age, I will remove the passengers from our analysis. I am not happy by doing it, they are over 150 being removed but we will still keep over than 700 passengers to analyse

# %%
df_clean = df.copy()

del df_clean['Cabin']

df_clean = df_clean.dropna()

df_clean.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# The column PassengerId and Ticket will not give me any relevant statistical result, so they will be also removed.

# %%
del df_clean['PassengerId']
del df_clean['Ticket']

df_clean.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567251
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938648
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200

# %% [markdown]
# ## Exploring phase
# Now that the data is clean it is time to play with it. Let´s start with Age, we will verify if there is a major difference between the age of those who survived.

# %%
print("The total number of passengers were %d, from them only %d survived." 
      %(df_clean['Survived'].count(), df_clean[df_clean['Survived'] == 1]['Survived'].count()))
print("There is %d males and %d females in the cleaned data." 
      %(df_clean[df_clean['Sex'] == 'male']['Survived'].count(),
        df_clean[df_clean['Sex'] == 'female']['Survived'].count()))
# Out:
# The total number of passengers were 712, from them only 288 survived.
# There is 453 males and 259 females in the cleaned data.

# %% [markdown]
# Let´s check the Age, we will verify if there is a major difference between the age of those who survived.

# %%
hist = Histogram(df_clean, values='Age', title="Age of passagers Histogram", plot_width=400, plot_height=400)
hist2 = Histogram(df_clean, values='Age', color='Survived', legend='top_right',
                  title="Age of passagers Histogram if Survived or not", plot_width=400, plot_height=400)

show(row(hist,hist2))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="41c630e3-d5d5-4e34-b8fa-87ae01c84a9c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("41c630e3-d5d5-4e34-b8fa-87ae01c84a9c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '41c630e3-d5d5-4e34-b8fa-87ae01c84a9c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ceddc80b-d192-4a79-b622-69bae6d92314":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(12.4, 16.3]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[31.0],"label":["(12.4, 16.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.979000000000001],"x":["14.35"],"y":[15.5]}},"id":"b572332e-8461-46c7-bb61-4845584b87f4","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"4fae1d4d-dac0-46b9-9740-42006a23019f","type":"ColumnDataSource"},"glyph":{"id":"d861dc46-8571-47bf-8a45-9183ed1c9206","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"70168c14-3081-4408-98b4-4d9ef5f6806e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(14.7, 19.2]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[52.0],"label":["(14.7, 19.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.5625],"x":["16.95"],"y":[26.0]}},"id":"07963a3c-9446-4123-9f65-d3131ff280ce","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(5.6, 10.1]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[13.0],"label":["(5.6, 10.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.5625],"x":["7.85"],"y":[6.5]}},"id":"116f8be7-9d69-48e0-869a-42afba9a3c3f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a5425b67-f17b-4316-b74c-db1dff08a260","type":"Rect"},{"attributes":{"data_source":{"id":"1f333760-d6d9-406f-935f-b050a9a7b805","type":"ColumnDataSource"},"glyph":{"id":"d7ca8d0d-2fc6-4453-aad8-9ba7863874c7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"940f95fb-5bc7-4510-8367-5eea58d306ec","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0ea8ac51-9d46-4afa-b174-aede121088dd","type":"Rect"},{"attributes":{"data_source":{"id":"d57d5619-302a-439a-b208-ffbaddf78828","type":"ColumnDataSource"},"glyph":{"id":"1311f41c-3d74-4ae2-bef9-d9e1ae6792bd","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"aa6dd86f-5dd2-474b-952a-19ae17f8d35e","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"228268a1-5ddc-482a-b183-6afc4b5a1ca7","type":"Rect"},{"attributes":{},"id":"6aea631b-8853-4d95-83e1-e1b37d319134","type":"ToolEvents"},{"attributes":{"data_source":{"id":"0e75b035-edfb-44ae-96d2-7f563f98657d","type":"ColumnDataSource"},"glyph":{"id":"20fd78a4-d6ba-4664-bfb7-9d4ddd3dca83","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a09f6c2d-2322-4006-a189-6271e2d4cc65","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bcc26e42-9db4-4a47-a47f-755770f3a763","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","unit ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %% [markdown]
# It surprised me that most of the babies (below 5) survived and someone above 75. But it is not much to play with it.
#
# Let's check if there is a difference for 'Sex'.

# %%
hist = Histogram(df_clean, values='Survived', color='Sex', legend='top_right',
                  title="Age of passagers Histogram if Survived or not", plot_width=400, plot_height=400)
hist2 = Histogram(df_clean, values='Age', color='Sex', legend='top_right',
                  title="Age of passagers Histogram if Survived or not", plot_width=400, plot_height=400)

show(row(hist,hist2))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="4c9d87d5-f414-481b-b961-b248e8c26207"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4c9d87d5-f414-481b-b961-b248e8c26207");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4c9d87d5-f414-481b-b961-b248e8c26207' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"102960c1-1fb3-4158-91f6-7d0398ec5bae":{"roots":{"references":[{"attributes":{"data_source":{"id":"2dacdc39-bba4-4b44-9f73-8478d5922bed","type":"ColumnDataSource"},"glyph":{"id":"e5b15227-432b-4a7e-b929-4fe1015694c4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"44eac3ed-572f-4abf-9ed9-1209c0a99477","type":"GlyphRenderer"},{"attributes":{},"id":"800bb330-b311-4a43-af9a-23cfbcbc9d8b","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5c0f68c1-3f1c-4114-8fd2-182cab32447b","type":"Rect"},{"attributes":{"plot":{"id":"b4b14485-b564-4740-ad83-ad00337f6915","subtype":"Chart","type":"Plot"}},"id":"555563e8-3da7-4c1c-b68b-888377dde6d6","type":"HelpTool"},{"attributes":{"below":[{"id":"1e6d4c10-5a74-412f-86f1-c0e858adf85d","type":"LinearAxis"}],"left":[{"id":"23b84383-825b-4f7b-a4eb-f56351bc6c47","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"89c66f2e-e5c6-4ce4-99c6-19cc52d4be19","type":"BoxAnnotation"},{"id":"4eb4199c-3854-4600-bffb-5e487f31b26d","type":"GlyphRenderer"},{"id":"5ff91110-9544-420c-80bc-7d2c85e84078","type":"GlyphRenderer"},{"id":"ec7f99ba-ec92-4f02-bf7c-95cf8bd37c4b","type":"GlyphRenderer"},{"id":"49bf3b58-a3bb-458a-988a-55459b9a14a3","type":"GlyphRenderer"},{"id":"1992a757-6469-43a7-996d-837fe10d4afa","type":"GlyphRenderer"},{"id":"ead2eb48-ae39-4c9c-b7b2-abb6477effcc","type":"GlyphRenderer"},{"id":"c774e20e-6589-409b-8fc4-562e95e7b7dc","type":"GlyphRenderer"},{"id":"fa321310-457a-4a0a-9e41-a5ec5a3356e4","type":"GlyphRenderer"},{"id":"298e29d0-fbd4-4955-97fb-721d7cd37233","type":"GlyphRenderer"},{"id":"e56605fb-f081-4788-9bc3-43ba20de6e42","type":"GlyphRenderer"},{"id":"f43bc870-279d-4841-8e01-778d9dc23cd1","type":"GlyphRenderer"},{"id":"4cbd0232-d8db-4310-8fdd-c49480e07f32","type":"GlyphRenderer"},{"id":"4dc621b1-590b-4151-a634-3b7889574b36","type":"GlyphRenderer"},{"id":"bf6ee5c4-33d0-401a-8b1a-e7f6567909f6","type":"GlyphRenderer"},{"id":"c317c78f-25ec-4d58-a01f-50f5e54a1304","type":"GlyphRenderer"},{"id":"045fbc7a-3a41-4d3e-b8bf-8fd80ca63797","type":"GlyphRenderer"},{"id":"2e6be1e5-c1dc-434e-9dbc-b24e7c8682bc","type":"GlyphRenderer"},{"id":"a44cc7d5-5af5-4908-9f45-cc35f82cc3e4","type":"GlyphRenderer"},{"id":"4fc827a1-d511-40ab-8928-0f290ba782f5","type":"GlyphRenderer"},{"id":"4e66277d-0537-4556-b39b-0d97b9e11796","type":"GlyphRenderer"},{"id":"9e413e82-3f0f-437f-8314-7779df7a241e","type":"GlyphRenderer"},{"id":"b5d115b6-09e2-4108-aa26-6ab8fb12021e","type":"GlyphRenderer"},{"id":"1439ce85-97c6-4bac-89ab-f2df680a56a1","type":"GlyphRenderer"},{"id":"983cf787-db2f-4122-9b58-6f75002a1a05","type":"GlyphRenderer"},{"id":"7bcca8be-fdc4-4e23-9ff5-e7364ccb84c5","type":"GlyphRenderer"},{"id":"cb0c2ae4-0591-4aa2-ae4d-8dbb90a6fd86","type":"GlyphRenderer"},{"id":"c503c9ac-cc1c-4405-9aa8-f26259c0fa57","type":"GlyphRenderer"},{"id":"44eac3ed-572f-4abf-9ed9-1209c0a99477","type":"GlyphRenderer"},{"id":"9e54208f-bf0b-4dde-8be0-85da6236d808","type":"GlyphRenderer"},{"id":"b1a798ae-d0e3-498a-a029-4e1b6f64a804","type":"Legend"},{"id":"1e6d4c10-5a74-412f-86f1-c0e858adf85d","type":"LinearAxis"},{"id":"23b84383-825b-4f7b-a4eb-f56351bc6c47","type":"LinearAxis"},{"id":"d8d05c0b-cb9f-4c5e-bbf2-8b58fad3dc62","type":"Grid"}],"title":{"id":"944bb30c-0534-401e-9bbb-19e94721b5c5","type":"Title"},"tool_events":{"id":"cf529269-7485-4d25-a262-9fde537a3c28","type":"ToolEvents"},"toolbar":{"id":"60950ed0-509c-4809-a83f-369852cee675","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"0920b3fb-71aa-4e66-b6cc-6a348f7b8000","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"edf04cc6-cf0b-4bb9-b7c2-36633651c8b6","type":"Range1d"}},"id":"b4b14485-b564-4740-ad83-ad00337f6915","subtype":"Chart","type":"Plot"},{"attributes":{"dat ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %% [markdown]
# Now it really surprised me. The amount of females that survived is a lot bigger them the mount of males.
#
# The age between males and females didn't change a lot. Since we checked something more interesting in the survival, let's play with it.
#
# To improve the understanding let's check one more graphic about the Sex and Survival.

# %%
df_female = df_clean[df_clean['Sex'] == 'female']
df_male = df_clean[df_clean['Sex'] == 'male']

female_survived = df_female[df_female['Survived'] == 1].loc[:,'Survived'].count()
female_not_survived = df_female[df_female['Survived'] == 0].loc[:,'Survived'].count()
male_survived = df_male[df_male['Survived'] == 1].loc[:,'Survived'].count()
male_not_survived = df_male[df_male['Survived'] == 0].loc[:,'Survived'].count()

df_simple = pd.DataFrame({'Sex': ['female', 'female', 'male', 'male'], 
             'Survived': ['Survived', 'Not survived', 'Survived', 'Not survived'], 
             'counting': [female_survived, female_not_survived, male_survived, male_not_survived]})

d = Donut(df_simple, label=['Sex','Survived'], values='counting')

show(d)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f69affaa-83d4-4f96-b397-9461ac8a4c93"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f69affaa-83d4-4f96-b397-9461ac8a4c93");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f69affaa-83d4-4f96-b397-9461ac8a4c93' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"aee74e87-5a1b-46dc-b4d3-3e72086316de":{"roots":{"references":[{"attributes":{},"id":"f5a22699-be46-45e1-a133-f406964ea192","type":"BasicTicker"},{"attributes":{"overlay":{"id":"58f56131-c43d-4df1-bc2f-414fa56ea6e2","type":"BoxAnnotation"},"plot":{"id":"38c3fc7a-e2c9-47b5-a19f-ac8c14ff09ee","subtype":"Chart","type":"Plot"}},"id":"e319260f-f577-4236-8a82-404b7159ba31","type":"BoxZoomTool"},{"attributes":{"location":"top_left","plot":{"id":"38c3fc7a-e2c9-47b5-a19f-ac8c14ff09ee","subtype":"Chart","type":"Plot"}},"id":"9b93a050-e530-489e-a8a6-cec89d4be687","type":"Legend"},{"attributes":{"below":[{"id":"e4a0113f-7e08-467e-917c-29981f378258","type":"LinearAxis"}],"left":[{"id":"be978ad0-280d-45a6-aa5e-480ff38c1bda","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"58f56131-c43d-4df1-bc2f-414fa56ea6e2","type":"BoxAnnotation"},{"id":"4e844bb3-3763-4e2b-9399-e402d5b5bca3","type":"GlyphRenderer"},{"id":"1a6882ce-a227-492a-9997-02b2c02ac207","type":"GlyphRenderer"},{"id":"9b93a050-e530-489e-a8a6-cec89d4be687","type":"Legend"},{"id":"e4a0113f-7e08-467e-917c-29981f378258","type":"LinearAxis"},{"id":"be978ad0-280d-45a6-aa5e-480ff38c1bda","type":"LinearAxis"}],"title":{"id":"09ba7e04-9f0b-40a1-801d-9764a9e5fb91","type":"Title"},"tool_events":{"id":"8cc3cf14-b3e1-4e25-83fd-2adb42d5e431","type":"ToolEvents"},"toolbar":{"id":"d34c6b58-63d5-403a-b511-b619c9fb03df","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"67db1033-c951-4db5-ad70-3d103b29b77c","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"3b378b22-354b-47ce-aa77-27a9055f810d","type":"Range1d"}},"id":"38c3fc7a-e2c9-47b5-a19f-ac8c14ff09ee","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"38c3fc7a-e2c9-47b5-a19f-ac8c14ff09ee","subtype":"Chart","type":"Plot"}},"id":"9fa7745c-6c62-4270-98f0-c14e6c07dba6","type":"HelpTool"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"3b378b22-354b-47ce-aa77-27a9055f810d","type":"Range1d"},{"attributes":{"data_source":{"id":"9169244a-8704-4d35-bcfa-b7453cfcfb19","type":"ColumnDataSource"},"glyph":{"id":"1cd40745-6d6f-43f0-aa0c-ed99c0c4169e","type":"AnnularWedge"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4e844bb3-3763-4e2b-9399-e402d5b5bca3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x","text_angle","text"],"data":{"text":["female","Not survived","Survived","male","Not survived","Survived"],"text_angle":[0.0,0.2823903508844758,1.4251888021200887,0.0,7.015635279786196,5.872836828550582],"x":[0.46693136878687336,2.160882239273503,0.3264604925898385,-0.4669313687868731,-1.6729612992851466,2.063209185677091],"y":[1.0235233738624716,0.6269672622971073,2.226190366248583,-1.0235233738624718,-1.5045598994703246,-0.8975900267592519]}},"id":"90d169a2-cdf0-4647-b7e2-63d7c1124b68","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["Sex_Survived","end","inners","level","color","start","values","outers","centers"],"data":{"Sex_Survived":[["female",""],["female","Not survived"],["female","Survived"],["male",""],["male","Not survived"],["male","Survived"]],"centers":[1.125,2.25,2.25,1.125,2.25,2.25],"color":["#f22c40","#f22c40","#f22c40","#5ab738","#5ab738","#5ab738"],"end":[2.2855969024712257,0.5647807017689516,2.2855969024712257,6.283185307179586,5.462488349921578,6.283185307179586],"inners":[0.0,1.5,1.5,0.0,1.5,1.5],"level":[0.0,1.0,1.0,0.0,1.0,1.0],"outers":[1.5,3.0,3.0,1.5,3.0,3.0],"start":[0.0,0.0,0.5647807017689516,2.2855969024712257,2.2855969024712257,5.462488349921578],"values":[259,64,195,453,360,93]}},"id":"9169244a-8704-4d35-bcfa-b7453cfcfb19","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"38c3fc7a-e2c9-47b5-a19f-ac8c14ff09ee","subtype":"Chart","type":"Plot"}},"id":"4c09eea7-9ecf-440a-8118-80f1177be6d6","type":"SaveTool"},{"attributes":{"data_source":{"id":"90d169a2-cdf0-4647-b7e2-63d7c1124b68","type":"ColumnDataSource"},"glyph":{"id": ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[10]</strong>&gt;</code></p>

# %% [markdown]
# Again we can clearly see that females survived a lot more than man.

# %%
def survival_rate(sex):
    df_one_sex = df_clean[df_clean['Sex'] == sex]
    count_survivals = df_one_sex[df_one_sex['Survived'] == 1].loc[:,'Survived'].count()
    count_one_sex = df_one_sex['Survived'].count()
    return float(count_survivals)/count_one_sex

survival_rate_male = survival_rate('male')
survival_rate_female = survival_rate('female')

print("The survival rate for males were %.2f and for females were %.2f." %(survival_rate_male, survival_rate_female))
# Out:
# The survival rate for males were 0.21 and for females were 0.75.

# %% [markdown]
# I am suprised again, I didn't expect that much difference in the percentages. I will try to statistically indicate that the survival rate for the females in the titanic were higher than the males.

# %% [markdown]
# # Statistical analysis
# Now that the data is already known we will try to draw some conclusions. Here the question is: Does females had a higher chance of survival than males in the titanic?
#
# Here will we try to show the statistical significance that the average survival rate for the females in the titanic were higher than the survival rate for the males.
#
# We will draw 1000 random samples of 20 subjects for each, show the histogram of the survival rate for the samples and check if the average survival rate for females is significant higher than for the males.
#
# We will use the critical value of 0.05 and we will use the t-test.
#
# So Hypotesis 0:
# average survival rate of females <= average survival rate of males
#
# Alternative Hypotesis:
# average survival rate of females > average survival rate of males

# %%
SIZE_SAMPLE = 20
TOTAL_SIZE = 1000

def sample(sex,size_sample):
    indexes = Set([])
    while len(indexes) < size_sample:
        df_one_sex = df_clean[df_clean['Sex'] == sex]
        indexes.add(random.choice(df_one_sex.index))
    return indexes

def survival_rate_of_sample(indexes):
    survivals = []
    for index in indexes:
        survivals.append(df_clean.loc[index,'Survived'])
    return float(sum(survivals))/len(survivals)

def survival_rate_list(sex,total_size,size_sample):
    samples_surv_rate = []
    for num_sample in range(total_size):
        samples_surv_rate.append(survival_rate_of_sample(sample(sex,size_sample)))
    return samples_surv_rate
    

survival_rate_list_male = survival_rate_list('male',TOTAL_SIZE,SIZE_SAMPLE)
survival_rate_list_female = survival_rate_list('female',TOTAL_SIZE,SIZE_SAMPLE)

# %% [markdown]
# Note: there is a chance of keeping twice the same survival rate (if the 20 samples are the same). Since the chance is extremely small we are ignoring it.

# %%
data = pd.DataFrame({'Sex': [], 'survival_rate': []})

for survival_rate_male in survival_rate_list_male:
    data = data.append({'Sex': 'male', 'survival_rate': survival_rate_male},ignore_index=True)
for survival_rate_female in survival_rate_list_female:
    data = data.append({'Sex': 'female', 'survival_rate': survival_rate_female},ignore_index=True)

# %%
hist = Histogram(data, values='survival_rate', color='Sex', title="Survival rate for sex Histogram",
                 plot_width=400, plot_height=400, legend='top_center')

show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="6c3d5174-d373-4d36-830b-a791b73aba79"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6c3d5174-d373-4d36-830b-a791b73aba79");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6c3d5174-d373-4d36-830b-a791b73aba79' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3038807f-18d6-4b2c-9fa2-4dc945591c4f":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.1, 0.2]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[215.0],"label":["(0.1, 0.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.01999999999999999],"x":["0.15"],"y":[107.5]}},"id":"8bd56698-127d-4242-b4e0-bf94b81b51a2","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.8, 0.8]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[213.0],"label":["(0.8, 0.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.020000000000000018],"x":["0.8"],"y":[106.5]}},"id":"d06ac89e-6f4c-42dd-8523-656ad25397ec","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"38eeefd4-bf52-45fb-818a-f743e1761597","type":"ColumnDataSource"},"glyph":{"id":"be495910-c49d-4c87-ace7-00b324518af0","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5e8beba1-2da0-42f4-8186-4970364fb787","type":"GlyphRenderer"},{"attributes":{},"id":"9dcf5c23-a62a-48a6-99c7-79f70b96c83a","type":"BasicTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"47bf823d-929d-4794-a187-19d40c5c4855","type":"Rect"},{"attributes":{"data_source":{"id":"771a49c1-6efb-4c2d-b883-4e26166d3422","type":"ColumnDataSource"},"glyph":{"id":"47bf823d-929d-4794-a187-19d40c5c4855","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"633fb35a-7988-4332-93b1-cc2a2ffab8bd","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"e60f4ffb-3bef-4f2b-a139-db5a291bdc37","type":"ColumnDataSource"},"glyph":{"id":"bf8bf789-224f-46f7-a9c4-d144fc23d75e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a7a4bde8-8d12-4239-bf7b-f9587038623b","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bf8bf789-224f-46f7-a9c4-d144fc23d75e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cd0e08f5-c551-42f7-a2cd-f0468deb4d0d","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.4, 0.4]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.4, 0.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.020000000000000018],"x":["0.4"],"y":[0.0]}},"id":"e15bdfcc-36b7-4c4b-9440-3de0bade02d3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e1ba76d2-979f-46c0-a719-2202f6ddc607","type":"ColumnDataSource"},"glyph":{"id":"6e34ed5d-8e9a-4654-b61c-fc6069ce9527","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"233cc3a9-f9e6-4444-9da3-c77e9c50c2e3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.2, 0.2]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.2, 0.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.020000000000000018],"x":["0.2"],"y":[0.0]}},"id":"771a49c1-6efb-4c2d-b883-4e26166d3422","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"ca99a760-45a2-4ef9-bab8 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %% [markdown]
# We want to check the difference so we will analyse the female survival rate - male survival rate

# %%
survival_rate_difference = np.array(survival_rate_list_female) - np.array(survival_rate_list_male)

hist = Histogram(pd.DataFrame({'Survival rate difference': survival_rate_difference}),
                 title="Survival rate difference Histogram", plot_width=400, plot_height=400)

show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="ccd7240f-0ae0-4aee-bb9f-4455dd0fb95e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ccd7240f-0ae0-4aee-bb9f-4455dd0fb95e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ccd7240f-0ae0-4aee-bb9f-4455dd0fb95e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"54e326af-6cf9-4602-aa21-b49f7afddd4b":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.8, 0.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[8.0],"label":["(0.8, 0.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03947368421052633],"x":["0.85"],"y":[4.0]}},"id":"b79795d7-b5be-4531-bef7-13b4a35c5ea4","type":"ColumnDataSource"},{"attributes":{},"id":"db45f52b-a7ef-4303-9330-b7405f92bec6","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.3, 0.4]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[39.0],"label":["(0.3, 0.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03947368421052633],"x":["0.35"],"y":[19.5]}},"id":"d2a45a1e-dc7e-42c6-8713-c613b99ee7fc","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.5, 0.6]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[165.0],"label":["(0.5, 0.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03947368421052633],"x":["0.55"],"y":[82.5]}},"id":"e8ae421d-6915-4606-b037-5f0bd5e88e21","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.4, 0.4]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[72.0],"label":["(0.4, 0.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03947368421052627],"x":["0.4"],"y":[36.0]}},"id":"a596228c-e651-428f-bd80-98822d0893e1","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":0.9472368421052632,"start":0.15276315789473685},"id":"fcc91d54-d157-4971-9e19-5e9c40de6c12","type":"Range1d"},{"attributes":{"dimension":1,"plot":{"id":"760178e6-a58f-4463-8f60-aa1b62965aa3","subtype":"Chart","type":"Plot"},"ticker":{"id":"4fc31661-fb0e-4073-92eb-eeb766f0e466","type":"BasicTicker"}},"id":"dd71b731-730d-4087-9e57-8d9abfa10efa","type":"Grid"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.9, 0.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(0.9, 0.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03947368421052633],"x":["0.9"],"y":[0.5]}},"id":"a79a7d93-c45a-42b8-8126-5ab2acf536e1","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bae0fa06-0d29-48b8-badf-a54e304b8e42","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.3, 0.3]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[24.0],"label":["(0.3, 0.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03947368421052627],"x":["0.3"],"y":[12.0]}},"id":"47d85067-7a6e-45fb-85e7-2fe517789828","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a6d5773d-cfbc-47f8-a432-84e26a11ce8b","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.6, 0.7]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[127.0],"label":["(0.6, 0.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03947368421052633],"x":["0.65"],"y":[63.5]}},"id":"2d935121-df ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[15]</strong>&gt;</code></p>

# %%
print('The mean is %.2f and the standard deviation is %.2f.' %(survival_rate_difference.mean(),survival_rate_difference.std()))
# Out:
# The mean is 0.55 and the standard deviation is 0.12.

# %%
t_statistic = survival_rate_difference.mean()/(survival_rate_difference.std()/SIZE_SAMPLE**0.5)

print('The t-statistic is %.2f.' %t_statistic)
# Out:
# The t-statistic is 19.68.

# %% [markdown]
# The degree of freedom is 19.
#
# The t-critical is 1.729. (Remember we are only checking if it is higher, one direction.)

# %% [markdown]
# # Conclusion
# Since t-statistical is a lot higher than t-critical we can say that we drop the initial hypotesis and assume that the average survival rate for females is significant higher than the average survival rate for males.
#
# So answering the question in the begining of the statistical analysis: Does females had a higher chance of survival than males in the titanic?
#
# The answer is: Yes. We can say if 95% certainty that females had a higher chance of survival than males.
