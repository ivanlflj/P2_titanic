# %% [markdown]
# # P2 - Data Analyst
#
# ## Importing
# Import libraries and CSV. Verify if CSV was imported correctly.

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from bokeh.plotting import figure
from bokeh.charts import Histogram
from bokeh.io import output_notebook, show
from bokeh.layouts import row
import random
from sets import Set

output_notebook()

df = pd.read_csv('titanic_data.csv')
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:12: DeprecationWarning: the sets module is deprecated
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4b8453a1-5691-4a6d-84c1-f526ccc2c973">Loading BokehJS ...</span>
#     </div>

# %%
df.describe()
# Out:
# C:\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male   NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500          NaN        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500          NaN        S
# 5        0            330877    8.4583          NaN        Q
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750          NaN        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500          NaN        S
# 13       5            347082   31.2750          NaN        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 16       1            382652   29.1250          NaN        Q
# 17       0            244373   13.0000          NaN        S
# 18       0            345763   18.0000          NaN        S
# 19       0              2649    7.2250          NaN        C
# 20       0            239865   26.0000          NaN        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292          NaN        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 26       0              2631    7.2250          NaN        C
# 27       2             19950  263.0000  C23 C25 C27        S
# 28       0            330959    7.8792          NaN        Q
# 29       0            349216    7.8958          NaN        S
# ..     ...               ...       ...          ...      ...
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000          NaN        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 878      0            349217    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Data Cleaning
# The 'Age' has some NaN and we must fix it.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# From a total of 891 passengers, we don't have the Age of 177, the Cabin of 687 and the Place of Embark for 2.
#
# We can consider that Cabin is nearly useless and remove this column.
#
# For the Place of Embark and Age, I will remove the passengers from our analysis. I am not happy by doing it, they are over 150 being removed but we will still keep over than 700 passengers to analyse

# %%
df_clean = df.copy()

del df_clean['Cabin']

df_clean = df_clean.dropna()

df_clean.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# The column PassengerId and Ticket will not give me any relevant statistical result, so they will be also removed.

# %%
del df_clean['PassengerId']
del df_clean['Ticket']

df_clean.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567251
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938648
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200

# %% [markdown]
# ## Exploring phase
# Now that the data is clean it is time to play with it. Let´s start with Age, we will verify if there is a major difference between the age of those who survived.

# %%
print("The total number of passengers were %d, from them only %d survived." 
      %(df_clean['Survived'].count(), df_clean[df_clean['Survived'] == 1]['Survived'].count()))
print("There is %d males and %d females in the cleaned data." 
      %(df_clean[df_clean['Sex'] == 'male']['Survived'].count(),
        df_clean[df_clean['Sex'] == 'female']['Survived'].count()))
# Out:
# The total number of passengers were 712, from them only 288 survived.
# There is 453 males and 259 females in the cleaned data.

# %% [markdown]
# Let´s check the Age, we will verify if there is a major difference between the age of those who survived.

# %%
hist = Histogram(df_clean, values='Age', title="Age of passagers Histogram", plot_width=400, plot_height=400)
hist2 = Histogram(df_clean, values='Age', color='Survived', legend='top_right',
                  title="Age of passagers Histogram if Survived or not", plot_width=400, plot_height=400)

show(row(hist,hist2))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="408a4735-ffa1-4f09-b625-176ba80f5bd2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("408a4735-ffa1-4f09-b625-176ba80f5bd2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '408a4735-ffa1-4f09-b625-176ba80f5bd2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c29e071d-2e63-4342-939e-c7c8a9ccabbe":{"roots":{"references":[{"attributes":{"plot":{"id":"8b1956a0-882d-4688-b56c-ced42f3d5f24","subtype":"Chart","type":"Plot"}},"id":"0fc9dc34-61d1-41dd-9e5d-1f7bdda3b372","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c312f40d-0950-4abb-8bc3-aee8df895b6b","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(24.3, 28.3]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[85.0],"label":["(24.3, 28.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.978999999999999],"x":["26.3"],"y":[42.5]}},"id":"1e4dce3f-355f-4636-a3f9-94039dc2aad3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"816a1827-50b5-48ca-a7ed-81b669679246","type":"ColumnDataSource"},"glyph":{"id":"b9c82d46-8cdc-44e1-9694-2b07915b53dd","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"84760c4e-1cfd-4f47-8374-fc17a457dda4","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b64dedb7-3a10-44d9-9cab-42eace69fdc8","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(42.1, 46.6]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[22.0],"label":["(42.1, 46.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.5625],"x":["44.35"],"y":[11.0]}},"id":"212ab733-44bf-4168-bc71-963f69f14d45","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(69.4, 74.0]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[6.0],"label":["(69.4, 74.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.5625],"x":["71.7"],"y":[3.0]}},"id":"ed094ad7-abe7-4c98-a10c-ede07ac529a5","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(50.2, 55.1]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[10.0],"label":["(50.2, 55.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.973750000000003],"x":["52.65"],"y":[5.0]}},"id":"587078a4-28a3-4625-b98a-5fc37f021109","type":"ColumnDataSource"},{"attributes":{},"id":"c50d8665-a639-4833-a5dd-b833b0b26992","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(76.0, 80.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(76.0, 80.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.978999999999999],"x":["78.0"],"y":[0.5]}},"id":"ceba3ebb-f98c-4c57-b2ef-fb4b9372b9ef","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e786835-3f23-4009-9d9c-a56aac06c5a6","type":"Rect"},{"attributes":{},"id":"09b2d8cc-c2dd-4374-9de7-86a64ab017d9","type":"BasicTicker"},{"attributes":{"data_source":{"id":"12bd0c39-7de9-429a-8023-48ac5b20b036","type":"ColumnDataSource"},"glyph":{"id":"7c113727-9381-4aaa-90f4-a94b6f2d4866","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"280f2040-2b7c-48db-b26b-00eeda97b5d4","type":"GlyphRenderer"},{"attributes":{},"id":" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %% [markdown]
# It surprised me that most of the babies (below 5) survived and someone above 75. But it is not much to play with it.
#
# Let's check if there is a difference for 'Sex'.

# %%
hist = Histogram(df_clean, values='Survived', color='Sex', legend='top_right',
                  title="Age of passagers Histogram if Survived or not", plot_width=400, plot_height=400)
hist2 = Histogram(df_clean, values='Age', color='Sex', legend='top_right',
                  title="Age of passagers Histogram if Survived or not", plot_width=400, plot_height=400)

show(row(hist,hist2))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="d0c0e40e-92b0-4e61-90fb-dab615bbd454"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d0c0e40e-92b0-4e61-90fb-dab615bbd454");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd0c0e40e-92b0-4e61-90fb-dab615bbd454' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a3e1ccf3-12b1-4f45-b44b-6aa961d12681":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(26.7, 31.9]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[39.0],"label":["(26.7, 31.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[5.1875],"x":["29.3"],"y":[19.5]}},"id":"849b029f-6c57-4e81-8114-05aceb31c913","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"0462276d-ab3e-42dd-931f-df86741f195d","type":"ColumnDataSource"},"glyph":{"id":"2ad1c168-7c2b-47c3-a24f-c60a6578a848","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3805c2f6-d187-4314-ba8a-82449a17de46","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(75.3, 80.0]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[1.0],"label":["(75.3, 80.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.681176470588241],"x":["77.65"],"y":[0.5]}},"id":"25a8e8aa-8cc6-4088-8cc2-8f01d092b182","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(11.1, 16.3]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[17.0],"label":["(11.1, 16.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[5.1875],"x":["13.7"],"y":[8.5]}},"id":"a855f2b3-7889-4280-80dd-d9f7c4a66b69","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"14487848-049d-4f6d-9fbc-97ff1bbc6a62","type":"Rect"},{"attributes":{"data_source":{"id":"3e002a1a-2574-4c7f-9c66-bdd7ee1ddfa0","type":"ColumnDataSource"},"glyph":{"id":"4acd5617-5221-4e8a-9dee-3529a25e1923","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d8c7ed07-e379-42ad-a718-226c42588716","type":"GlyphRenderer"},{"attributes":{"axis_label":"Count( Age )","formatter":{"id":"1c8d2be1-77ad-475d-ab3c-eb3c95971f26","type":"BasicTickFormatter"},"plot":{"id":"b2b81ef2-d1b0-4b5e-aecb-6d65b50101e2","subtype":"Chart","type":"Plot"},"ticker":{"id":"0b86db5c-94a1-4732-ac44-df8ea138732d","type":"BasicTicker"}},"id":"740d4dec-65a8-4d1e-a379-a9a6a81bffba","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(9.8, 14.5]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[7.0],"label":["(9.8, 14.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.681176470588236],"x":["12.15"],"y":[3.5]}},"id":"cd61c5ca-131b-4941-9e9d-4206cf792119","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.7, 1.0]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[195.0],"label":["(0.7, 1.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.33333333333333337],"x":["0.85"],"y":[97.5]}},"id":"d9045244-eb73-41ac-889d-c3667dc113ed","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"71e30489-f82c-4b56-9038-23cc248d0218","type":"ColumnDataSource"},"glyph":{"id":"b2c6cb05-325b-46cf-a6ce-eb57f35e7433","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5f90c77f-f6ed-4ed7-b7c7-3736ac07c3f2","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(70.6, 75.3]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[3.0],"label":["(70.6, 75.3]"],"line_alpha":[1.0],"line_color":["black"],"width ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %% [markdown]
# Now it really surprised me. The amount of females that survived is a lot bigger them the mount of males.
#
# The age between males and females didn't change a lot. Since we checked something more interesting in the survival, let's play with it.

# %%
def survival_rate(sex):
    df_one_sex = df_clean[df_clean['Sex'] == sex]
    count_survivals = df_one_sex[df_one_sex['Survived'] == 1].loc[:,'Survived'].count()
    count_one_sex = df_one_sex['Survived'].count()
    return float(count_survivals)/count_one_sex

survival_rate_male = survival_rate('male')
survival_rate_female = survival_rate('female')

print("The survival rate for males were %.2f and for females were %.2f." %(survival_rate_male, survival_rate_female))
# Out:
# The survival rate for males were 0.21 and for females were 0.75.

# %% [markdown]
# I am suprised again, I didn't expect that much difference in the percentages. I will try to statistically indicate that the survival rate for the females in the titanic were higher than the males.

# %% [markdown]
# # Statistical analysis
# Here will we try to show the statistical significance that the average survival rate for the females in the titanic were higher than the survival rate for the males.
#
# We will draw 1000 random samples of 20 subjects for each, show the histogram of the survival rate for the samples and check if the average survival rate for females is significant higher than for the males.
#
# We will use the critical value of 0.05 and we will use the t-test.
#
# So Hypotesis 0:
# average survival rate of females <= average survival rate of males
#
# Alternative Hypotesis:
# average survival rate of females > average survival rate of males

# %%
SIZE_SAMPLE = 20
TOTAL_SIZE = 1000

def sample(sex,size_sample):
    indexes = Set([])
    while len(indexes) < size_sample:
        df_one_sex = df_clean[df_clean['Sex'] == sex]
        indexes.add(random.choice(df_one_sex.index))
    return indexes

def survival_rate_of_sample(indexes):
    survivals = []
    for index in indexes:
        survivals.append(df_clean.loc[index,'Survived'])
    return float(sum(survivals))/len(survivals)

def survival_rate_list(sex,total_size,size_sample):
    samples_surv_rate = []
    for num_sample in range(total_size):
        samples_surv_rate.append(survival_rate_of_sample(sample(sex,size_sample)))
    return samples_surv_rate
    

survival_rate_list_male = survival_rate_list('male',TOTAL_SIZE,SIZE_SAMPLE)
survival_rate_list_female = survival_rate_list('female',TOTAL_SIZE,SIZE_SAMPLE)

# %% [markdown]
# Note: there is a chance of keeping twice the same survival rate (if the 20 samples are the same). Since the chance is extremely small we are ignoring it.

# %%
data = pd.DataFrame({'Sex': [], 'survival_rate': []})

for survival_rate_male in survival_rate_list_male:
    data = data.append({'Sex': 'male', 'survival_rate': survival_rate_male},ignore_index=True)
for survival_rate_female in survival_rate_list_female:
    data = data.append({'Sex': 'female', 'survival_rate': survival_rate_female},ignore_index=True)

# %%
hist = Histogram(data, values='survival_rate', color='Sex', title="Survival rate for sex Histogram",
                 plot_width=400, plot_height=400, legend='top_center')

show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="6fe301c9-ba98-4241-8aa9-00594c0d955e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6fe301c9-ba98-4241-8aa9-00594c0d955e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6fe301c9-ba98-4241-8aa9-00594c0d955e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5a16572c-7d4c-467d-881b-43c7e3d09ab2":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e8f19449-9a89-438f-88ea-5c1cadcdb729","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.4, 0.4]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.4, 0.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.020000000000000018],"x":["0.4"],"y":[0.0]}},"id":"999a83ce-fab7-46bf-be91-0b25a9aa6cfd","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.5, 0.5]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.5, 0.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.019999999999999962],"x":["0.5"],"y":[0.0]}},"id":"6775a949-3427-4d37-9a74-699f569b3fa4","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"2009744a-1b4c-475b-ad1e-a7fad93bc062","type":"ColumnDataSource"},"glyph":{"id":"80e4dcba-77b3-4a08-baa6-6af8850d448d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a535d2c6-451a-4181-a7cb-60ed503fd051","type":"GlyphRenderer"},{"attributes":{},"id":"d712e79a-6e85-442d-814f-1ff995f26084","type":"BasicTicker"},{"attributes":{"data_source":{"id":"dee6b956-c833-41c4-89c8-cace23ed59ee","type":"ColumnDataSource"},"glyph":{"id":"472ecfa4-b955-4319-bdd4-16f9b7ef0774","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"66280128-2b40-4a24-879a-69de12001274","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.7, 0.7]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.7, 0.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.019642857142857073],"x":["0.7"],"y":[0.0]}},"id":"5e916e75-613f-460b-b300-13102d063dda","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.3, 0.3]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.3, 0.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.019999999999999962],"x":["0.3"],"y":[0.0]}},"id":"c24245c2-be9a-4bf8-a2e6-f47924186b40","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["[0.5, 0.5]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[2.0],"label":["[0.5, 0.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.01964285714285713],"x":["0.5"],"y":[1.0]}},"id":"5c568ba9-e650-404e-9d1c-2fdd667a7cf0","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"099d84fe-6d74-4df8-9c78-8918381240ca","type":"ColumnDataSource"},"glyph":{"id":"2b4d80c5-1a7d-453c-81e6-318dfb22bc57","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ecd7f771-9872-4caa-ae26-7c0269de7a68","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"a97ece50-f761-4410-a052-19b0228f4a51","type":"ColumnDataSource"},"glyph":{"id":"0017ea23-5e4b-4570-83a7-791499402fe5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b056c9dd-8764-4b2e-9ab1-296c2fbf449d","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.5, 0.5]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.5, 0.5]"],"line_alpha" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[13]</strong>&gt;</code></p>

# %% [markdown]
# We want to check the difference so we will analyse the female survival rate - male survival rate

# %%
survival_rate_difference = np.array(survival_rate_list_female) - np.array(survival_rate_list_male)

hist = Histogram(pd.DataFrame({'Survival rate difference': survival_rate_difference}),
                 title="Survival rate difference Histogram", plot_width=400, plot_height=400)

show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="28fd0d04-8be0-484f-916c-845102774df8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("28fd0d04-8be0-484f-916c-845102774df8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '28fd0d04-8be0-484f-916c-845102774df8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9f22aa72-a2f3-4b46-84dc-b6236a46c7d7":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.5, 0.5]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[148.0],"label":["(0.5, 0.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03947368421052633],"x":["0.5"],"y":[74.0]}},"id":"aaa2dc96-f79b-463a-bf64-5dbc89da1fe4","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.8, 0.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(0.8, 0.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03947368421052633],"x":["0.85"],"y":[2.0]}},"id":"aa56fb54-25e6-418a-ad69-8fe21996ed86","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8ff64b2c-0da0-4dc0-bafa-b71019f250f8","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.6, 0.6]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[148.0],"label":["(0.6, 0.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03947368421052633],"x":["0.6"],"y":[74.0]}},"id":"85588c55-d539-43b9-97a6-11baf9ffaf0f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"56919aae-fb90-47ca-ba5c-37cab114c109","type":"ColumnDataSource"},"glyph":{"id":"2c90cfa4-e221-4ada-b0be-6426f06bc2df","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"027a6ad2-8f9b-417d-af0a-466f7d848da8","type":"GlyphRenderer"},{"attributes":{},"id":"e9d819d1-a442-4e8a-abc6-76a3b623967a","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4c8196e2-2460-413a-80b1-c2e716a1a3d5","type":"Rect"},{"attributes":{"data_source":{"id":"80a40b29-9baf-4763-bbce-eff462cc31dd","type":"ColumnDataSource"},"glyph":{"id":"1a1f1e95-deac-4aed-8203-71ad7cb42deb","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"345dfca7-c4e4-45be-be83-fa4b2817f68e","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"eeabe9c6-0e1f-42df-af12-f183db0552f5","type":"BoxAnnotation"},"plot":{"id":"8773911b-df7e-49cc-ba3f-1467b21eebd3","subtype":"Chart","type":"Plot"}},"id":"a03ca8e6-9c1c-4eb2-a1f1-c87720ad2e11","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"8773911b-df7e-49cc-ba3f-1467b21eebd3","subtype":"Chart","type":"Plot"},"ticker":{"id":"1ee38551-98ab-4055-836d-f5879c56526a","type":"BasicTicker"}},"id":"4e9689aa-b131-4627-81e0-85a00a58d422","type":"Grid"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.7, 0.7]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[85.0],"label":["(0.7, 0.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03947368421052633],"x":["0.7"],"y":[42.5]}},"id":"f933c044-b1fc-476c-9084-a6e7dc7eba3c","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.7, 0.7]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.7, 0.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03947368421052633],"x":["0.7"],"y":[0.0]}},"id":"807b5e4a-7ba5-4983-a44c-8937c49c66b4","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color", ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %%
print('The mean is %.2f and the standard deviation is %.2f.' %(survival_rate_difference.mean(),survival_rate_difference.std()))
# Out:
# The mean is 0.55 and the standard deviation is 0.13.

# %%
t_statistic = survival_rate_difference.mean()/(survival_rate_difference.std()/SIZE_SAMPLE**0.5)

print('The t-statistic is %.2f.' %t_statistic)
# Out:
# The t-statistic is 19.40.

# %% [markdown]
# The degree of freedom is 19.
#
# The t-critical is 1.729. (Remember we are only checking if it is higher, one direction.)

# %% [markdown]
# # Conclusion
# Since t-statistical is a lot higher than t-critical we can say that we drop the initial hypotesis and assume that the average survival rate for females is significant higher than the average survival rate for males.
