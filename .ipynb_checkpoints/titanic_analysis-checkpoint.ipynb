# %% [markdown]
# # P2 - Data Analyst
#
# ## Introduction
# The idea here is to explore the data and look for some conclusions we can get from the data. At this moment no question can be formulated without a first knowledge of the data

# %% [markdown]
# ## Importing
# Import libraries and CSV. Verify if CSV was imported correctly.

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from bokeh.plotting import figure
from bokeh.charts import Histogram
from bokeh.charts import Donut
from bokeh.charts import Bar
from bokeh.io import output_notebook, show
from bokeh.layouts import row
import random
from sets import Set

output_notebook()

df = pd.read_csv('titanic_data.csv')
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:14: DeprecationWarning: the sets module is deprecated
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bdf25e9f-caf2-402c-8b87-523c592305ae">Loading BokehJS ...</span>
#     </div>

# %%
df.describe()
# Out:
# C:\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male   NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500          NaN        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500          NaN        S
# 5        0            330877    8.4583          NaN        Q
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750          NaN        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500          NaN        S
# 13       5            347082   31.2750          NaN        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 16       1            382652   29.1250          NaN        Q
# 17       0            244373   13.0000          NaN        S
# 18       0            345763   18.0000          NaN        S
# 19       0              2649    7.2250          NaN        C
# 20       0            239865   26.0000          NaN        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292          NaN        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 26       0              2631    7.2250          NaN        C
# 27       2             19950  263.0000  C23 C25 C27        S
# 28       0            330959    7.8792          NaN        Q
# 29       0            349216    7.8958          NaN        S
# ..     ...               ...       ...          ...      ...
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000          NaN        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 878      0            349217    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Data Cleaning
# The 'Age' has some NaN and we must fix it.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# From a total of 891 passengers, we don't have the Age of 177, the Cabin of 687 and the Place of Embark for 2.
#
# We can consider that Cabin is nearly useless and remove this column.
#
# For the Place of Embark and Age, I will remove the passengers from our analysis. I am not happy by doing it, they are over 150 being removed but we will still keep over than 700 passengers to analyse

# %%
df_clean = df.copy()

del df_clean['Cabin']

df_clean = df_clean.dropna()

df_clean.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# The column PassengerId and Ticket will not give me any relevant statistical result, so they will be also removed.

# %%
del df_clean['PassengerId']
del df_clean['Ticket']

df_clean.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567251
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938648
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200

# %% [markdown]
# ## Exploring phase
# Now that the data is clean it is time to play with it. Let´s start with Age, we will verify if there is a major difference between the age of those who survived.

# %%
print("The total number of passengers were %d, from them only %d survived." 
      %(df_clean['Survived'].count(), df_clean[df_clean['Survived'] == 1]['Survived'].count()))
print("There is %d males and %d females in the cleaned data." 
      %(df_clean[df_clean['Sex'] == 'male']['Survived'].count(),
        df_clean[df_clean['Sex'] == 'female']['Survived'].count()))
# Out:
# The total number of passengers were 712, from them only 288 survived.
# There is 453 males and 259 females in the cleaned data.

# %% [markdown]
# Let´s check the Age, we will verify if there is a major difference between the age of those who survived.

# %%
hist = Histogram(df_clean, values='Age', title="Age of passagers Histogram", plot_width=400, plot_height=400)
hist2 = Histogram(df_clean, values='Age', color='Survived', legend='top_right',
                  title="Age of passagers Histogram if Survived or not", plot_width=400, plot_height=400)

show(row(hist,hist2))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f94bc367-6402-499f-b0a9-4da59f939c95"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f94bc367-6402-499f-b0a9-4da59f939c95");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f94bc367-6402-499f-b0a9-4da59f939c95' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3fedb845-bdbb-4908-b294-5e42cca0904d":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba6e4961-d8bd-46c4-a5c8-9d6618967104","type":"Rect"},{"attributes":{"data_source":{"id":"5a38b710-bc75-4df3-90d3-289aebd3cac7","type":"ColumnDataSource"},"glyph":{"id":"c8982921-40fb-422e-be5f-0b3d453282de","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"79b41cdc-3a89-4e69-9fcf-c377d88a5056","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(72.0, 76.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(72.0, 76.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.978999999999999],"x":["74.0"],"y":[0.5]}},"id":"7cf75391-c000-4b38-a4e5-edcecc124114","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"718c1a51-6dcb-4215-8b31-5fe187b9bfa4","type":"Rect"},{"attributes":{"data_source":{"id":"b7d182e0-3580-4a57-ba5f-680c57b8bfbf","type":"ColumnDataSource"},"glyph":{"id":"d08f3be5-1949-4591-90c2-eebcee5656d8","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4b9d0bdf-f3c0-4a55-864c-e01ef7df0aa6","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4e35e69b-26fb-4bb3-9ac7-b62cacc9ce10","type":"Rect"},{"attributes":{"data_source":{"id":"d5f0abba-c659-452c-96ed-c4f58ba53d07","type":"ColumnDataSource"},"glyph":{"id":"9328c9c7-d2f1-4cb8-a97f-2e1d356cc325","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a903f473-4a8a-4505-b01b-60e75c2b8c50","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"edb45055-6218-44d4-9664-6f3b1b637aae","type":"ColumnDataSource"},"glyph":{"id":"4dd97a59-d0cc-4b2e-9fbe-7f25753a4232","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a37d368a-ffd2-47e1-a40c-58ee3a908463","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(30.3, 35.2]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[41.0],"label":["(30.3, 35.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.9737499999999955],"x":["32.75"],"y":[20.5]}},"id":"3ee43d96-a208-4814-961e-c049e20e3e83","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7e15980f-6120-4a0d-bb15-d49c1fe53058","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(69.4, 74.0]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[6.0],"label":["(69.4, 74.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.5625],"x":["71.7"],"y":[3.0]}},"id":"84e7fe4a-a23b-4bd2-b622-62e8ca8c5150","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(5.4, 10.4]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[7.0],"label":["(5.4, 10.4]"],"line_alpha":[1.0], ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %% [markdown]
# It surprised me that most of the babies (below 5) survived and someone above 75. But it is not much to play with it.
#
# Let's check if there is a difference for 'Sex'.

# %%
df_female = df_clean[df_clean['Sex'] == 'female']
df_male = df_clean[df_clean['Sex'] == 'male']

female_survived = df_female[df_female['Survived'] == 1].loc[:,'Survived'].count()
female_not_survived = df_female[df_female['Survived'] == 0].loc[:,'Survived'].count()
male_survived = df_male[df_male['Survived'] == 1].loc[:,'Survived'].count()
male_not_survived = df_male[df_male['Survived'] == 0].loc[:,'Survived'].count()

df_simple = pd.DataFrame({'Sex': ['female', 'female', 'male', 'male'], 
             'Survived': ['Survived', 'Not survived', 'Survived', 'Not survived'], 
             'counting': [female_survived, female_not_survived, male_survived, male_not_survived]})

bar = Bar(df_simple, values='counting', label='Survived', stack='Sex', legend='top_center',
                  title="Number of passengers if survived or not and divided by sex", plot_width=400, plot_height=400)
hist = Histogram(df_clean, values='Age', color='Sex', legend='top_right',
                  title="Age of passagers Histogram depending of the sex", plot_width=400, plot_height=400)

show(row(bar,hist))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="888692f1-996b-4168-aad8-004b3d28045f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("888692f1-996b-4168-aad8-004b3d28045f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '888692f1-996b-4168-aad8-004b3d28045f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d65567f2-5eed-40a1-a1a0-ab86bb0b212e":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"290894cb-214e-4789-9ffe-abc088d68f54","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ab5022da-c9ae-44de-9083-7ec026cc8871","subtype":"Chart","type":"Plot"}},"id":"be3bbbb4-3e75-4aad-9829-62c9d9ff40e9","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"bb889b95-a63b-4662-b002-4db0bb06bfbf","type":"ColumnDataSource"},"glyph":{"id":"0e1531c0-f04a-40e2-b076-496d5320ff1f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a4653465-d98b-4f5b-877f-f22067d6732c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(21.5, 26.7]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[43.0],"label":["(21.5, 26.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[5.1875],"x":["24.1"],"y":[21.5]}},"id":"902e611c-bd46-44b7-9028-2a8bde6e6873","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"02e09e51-32c3-4616-a517-6e736a8e50b1","type":"BoxAnnotation"},"plot":{"id":"733b97db-7f92-45be-9fbf-91e6928a38ee","subtype":"Chart","type":"Plot"}},"id":"cdd44532-186c-4021-bca0-35e22bef09a6","type":"BoxZoomTool"},{"attributes":{"overlay":{"id":"290894cb-214e-4789-9ffe-abc088d68f54","type":"BoxAnnotation"},"plot":{"id":"ab5022da-c9ae-44de-9083-7ec026cc8871","subtype":"Chart","type":"Plot"}},"id":"68d257c3-543d-47f6-aed0-7d2f393d5365","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(5.9, 11.1]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[11.0],"label":["(5.9, 11.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[5.1875],"x":["8.5"],"y":[5.5]}},"id":"acac3d84-a5f0-4b85-a458-153913f3f563","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"4901417a-b16f-4cfb-ad19-5faa972a9106","type":"ColumnDataSource"},"glyph":{"id":"2e79b94a-1e21-4980-9f47-20330701e5c3","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"170c1ecf-28c9-49cf-9e20-e091dec45bba","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"0a8e8abc-32a1-44ff-94bd-dcd6ef445e72","type":"ColumnDataSource"},"glyph":{"id":"d158ce77-ab91-4e5b-b9b3-fd400b353179","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6e72c3ea-db61-4ae4-8e3c-97c6a3d9df67","type":"GlyphRenderer"},{"attributes":{},"id":"ae300af5-d262-44c7-a30d-b142ea8584bd","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f1961d1-f38a-4fde-ad20-f1817a643d2a","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3e3430b1-98a0-4632-8852-035a64381fe4","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(9.8, 14.5]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[7.0],"label":["(9.8, 14.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.681176470588236],"x":["12.15"],"y":[3.5]}},"id":"0a8e8abc-32a1-44ff-94bd-dcd6ef445e72","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"a ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %% [markdown]
# Now it really surprised me. The amount of females that survived is a lot bigger them the mount of males.
#
# The age between males and females didn't change a lot. Since we checked something more interesting in the survival, let's play with it.
#
# To improve the understanding let's check one more graphic about the Sex and Survival.

# %%
d = Donut(df_simple, label=['Sex','Survived'], values='counting',
                  title="Quantity of passengers if survived or not and divided by sex")

show(d)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="b839b9e2-f414-4881-8f39-5e9c9933e8f0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b839b9e2-f414-4881-8f39-5e9c9933e8f0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b839b9e2-f414-4881-8f39-5e9c9933e8f0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7c63a30f-71ce-4c1d-b4c5-ec0618fc3475":{"roots":{"references":[{"attributes":{},"id":"093b4016-2d39-4f30-a2eb-2067d2deca82","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["Sex_Survived","end","inners","level","color","start","values","outers","centers"],"data":{"Sex_Survived":[["female",""],["female","Not survived"],["female","Survived"],["male",""],["male","Not survived"],["male","Survived"]],"centers":[1.125,2.25,2.25,1.125,2.25,2.25],"color":["#f22c40","#f22c40","#f22c40","#5ab738","#5ab738","#5ab738"],"end":[2.2855969024712257,0.5647807017689516,2.2855969024712257,6.283185307179586,5.462488349921578,6.283185307179586],"inners":[0.0,1.5,1.5,0.0,1.5,1.5],"level":[0.0,1.0,1.0,0.0,1.0,1.0],"outers":[1.5,3.0,3.0,1.5,3.0,3.0],"start":[0.0,0.0,0.5647807017689516,2.2855969024712257,2.2855969024712257,5.462488349921578],"values":[259,64,195,453,360,93]}},"id":"cbf9bb11-8cc9-4698-a14b-26206db51daa","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":3.1500000000000004,"start":-3.1500000000000004},"id":"885e131b-43ff-424a-9e1f-92f6bf4811d1","type":"Range1d"},{"attributes":{"data_source":{"id":"cbf9bb11-8cc9-4698-a14b-26206db51daa","type":"ColumnDataSource"},"glyph":{"id":"b049b679-b462-45fd-8384-5c21da8ff19f","type":"AnnularWedge"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"13bfb75a-37f7-4406-b0db-bc2653de1c93","type":"GlyphRenderer"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"b049b679-b462-45fd-8384-5c21da8ff19f","type":"AnnularWedge"},{"attributes":{},"id":"be3dde11-c410-4d09-90aa-e43b5f853e7b","type":"BasicTickFormatter"},{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7f99cc6c-5389-42a4-8d5c-07fe371d4a4c","type":"Text"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"61829778-2e92-4fd7-8ddf-1365c0463023","type":"PanTool"},{"id":"17996704-961c-4780-867b-642a9586079e","type":"WheelZoomTool"},{"id":"e985a6f5-eeac-4411-94ae-6d8b2eba3df2","type":"BoxZoomTool"},{"id":"6cbff0a3-039c-4172-b7d1-739c2f508b72","type":"SaveTool"},{"id":"5d934597-9d6b-4f13-ace7-764274a7f0b4","type":"ResetTool"},{"id":"d5ad5852-03d0-4b47-a86f-6e1338c476df","type":"HelpTool"}]},"id":"785384e2-b34e-4298-bacf-543741cf0ce8","type":"Toolbar"},{"attributes":{"data_source":{"id":"ed204535-6e9b-48e1-8a4c-25fd6044ce4b","type":"ColumnDataSource"},"glyph":{"id":"7f99cc6c-5389-42a4-8d5c-07fe371d4a4c","type":"Text"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c9df430d-bee5-4806-9b08-9a96cdddb1a9","type":"GlyphRenderer"},{"attributes":{"axis_label":null,"formatter":{"id":"093b4016-2d39-4f30-a2eb-2067d2deca82","type":"BasicTickFormatter"},"plot":{"id":"c47ee440-b535-4083-b7a9-b9cf1c099ce1","subtype":"Chart","type":"Plot"},"ticker":{"id":"aa3a128a-5c8d-4f90-b81b-1e0c80a95bb8","type":"BasicTicker"},"visible":false},"id":"b24e22ef-0f58-43b4-bf19-344c3b97c5d5","type":"LinearAxis"},{"attributes":{"below":[{"id":"ac155ea6-502f-4fd8-adb8-b818988a2337","type":"LinearAxis"}],"left":[{"id":"b24e22ef-0f58-43b4-bf19-344c3b97c5d5","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"b3002908-0892-4e70-a5e8-26df71cb41d6","type":"BoxAnnotation"},{"id":"13bfb75a-37f7-4406-b0db-bc2653de1c93","type":"GlyphRenderer"},{"id":"c9df430d-bee5-4806-9b08-9a96cdddb1a9","type":"GlyphRenderer"},{"id":"4e768084-9ec3-4b7d-9cf5-1add0621fcd0","type":"Legend"},{"id":"ac155ea6-502f-4fd8-adb8-b818988a2337","type":"LinearAxis"},{"id":"b24e22ef-0f58-43b4-bf19-344c3b97c5d5","type":"LinearAxis"}],"ti ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[10]</strong>&gt;</code></p>

# %% [markdown]
# Again we can clearly see that females survived a lot more than man.

# %%
def survival_rate(sex):
    df_one_sex = df_clean[df_clean['Sex'] == sex]
    count_survivals = df_one_sex[df_one_sex['Survived'] == 1].loc[:,'Survived'].count()
    count_one_sex = df_one_sex['Survived'].count()
    return float(count_survivals)/count_one_sex

survival_rate_male = survival_rate('male')
survival_rate_female = survival_rate('female')

print("The survival rate for males were %.2f and for females were %.2f." %(survival_rate_male, survival_rate_female))
# Out:
# The survival rate for males were 0.21 and for females were 0.75.

# %% [markdown]
# I am suprised again, I didn't expect that much difference in the percentages. I will try to statistically indicate that the survival rate for the females in the titanic were higher than the males.

# %% [markdown]
# # Statistical analysis
# Now that the data is already known we will try to draw some conclusions. Here the question is: Does females had a higher chance of survival than males in the titanic?
#
# Here will we try to show the statistical significance that the average survival rate for the females in the titanic were higher than the survival rate for the males.
#
# We will draw 1000 random samples of 20 subjects for each, show the histogram of the survival rate for the samples and check if the average survival rate for females is significant higher than for the males.
#
# We will use the critical value of 0.05 and we will use the t-test.
#
# So Hypotesis 0:
# average survival rate of females <= average survival rate of males
#
# Alternative Hypotesis:
# average survival rate of females > average survival rate of males

# %%
SIZE_SAMPLE = 20
TOTAL_SIZE = 1000

def sample(sex,size_sample):
    indexes = Set([])
    while len(indexes) < size_sample:
        df_one_sex = df_clean[df_clean['Sex'] == sex]
        indexes.add(random.choice(df_one_sex.index))
    return indexes

def survival_rate_of_sample(indexes):
    survivals = []
    for index in indexes:
        survivals.append(df_clean.loc[index,'Survived'])
    return float(sum(survivals))/len(survivals)

def survival_rate_list(sex,total_size,size_sample):
    samples_surv_rate = []
    for num_sample in range(total_size):
        samples_surv_rate.append(survival_rate_of_sample(sample(sex,size_sample)))
    return samples_surv_rate
    

survival_rate_list_male = survival_rate_list('male',TOTAL_SIZE,SIZE_SAMPLE)
survival_rate_list_female = survival_rate_list('female',TOTAL_SIZE,SIZE_SAMPLE)

# %% [markdown]
# Note: there is a chance of keeping twice the same survival rate (if the 20 samples are the same). Since the chance is extremely small we are ignoring it.

# %%
data = pd.DataFrame({'Sex': [], 'survival_rate': []})

for survival_rate_male in survival_rate_list_male:
    data = data.append({'Sex': 'male', 'survival_rate': survival_rate_male},ignore_index=True)
for survival_rate_female in survival_rate_list_female:
    data = data.append({'Sex': 'female', 'survival_rate': survival_rate_female},ignore_index=True)

# %%
hist = Histogram(data, values='survival_rate', color='Sex', title="Survival rate for sex Histogram",
                 plot_width=400, plot_height=400, legend='top_center')

show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="8bd02733-2da4-4cdf-b725-83d4041dd1de"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8bd02733-2da4-4cdf-b725-83d4041dd1de");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8bd02733-2da4-4cdf-b725-83d4041dd1de' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2abcdfbe-eb50-4dd3-8c4b-11e3bfa09138":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.5, 0.5]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[2.0],"label":["(0.5, 0.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.020000000000000018],"x":["0.5"],"y":[1.0]}},"id":"35353b93-4fed-4b1d-ac83-5624511351ad","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.0, 0.0]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.0, 0.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.02],"x":["0.0"],"y":[0.0]}},"id":"a357cdf3-9b80-4a7a-8eb3-e65001bfc305","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.5, 0.5]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.5, 0.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.019999999999999962],"x":["0.5"],"y":[0.0]}},"id":"7ca09e9e-0ba2-4b52-bd68-07588dae1d12","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.6, 0.6]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.6, 0.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.019642857142857184],"x":["0.6"],"y":[0.0]}},"id":"61531fd8-d0ce-4094-85bc-931ee81e6172","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.3, 0.3]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.3, 0.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.020000000000000018],"x":["0.3"],"y":[0.0]}},"id":"5b6bbb20-23d2-4ac1-807e-68f9ecf2e783","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1cc5b2d2-4745-46b9-9ac9-9d9713284fe9","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"50238113-118c-4441-b9ef-4c04ff70b855","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.8, 0.9]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[142.0],"label":["(0.8, 0.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.019642857142857073],"x":["0.85"],"y":[71.0]}},"id":"42c025cb-a0c3-43bf-8c03-2613bcfb000d","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"0536ecbd-e1e5-4418-ab4a-eab89bd56a94","type":"ColumnDataSource"},"glyph":{"id":"4abfc2f7-b769-496f-85d2-d08d97d73c85","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ee03a5d1-8f9b-49e1-ad35-2b6bf27b98e6","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7cee8bcc-c26c-4d7c-91b6-a16e0513db70","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"432ee8a8-309a-4 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %% [markdown]
# We want to check the difference so we will analyse the female survival rate - male survival rate

# %%
survival_rate_difference = np.array(survival_rate_list_female) - np.array(survival_rate_list_male)

hist = Histogram(pd.DataFrame({'Survival rate difference': survival_rate_difference}),
                 title="Survival rate difference Histogram", plot_width=400, plot_height=400)

show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="218bad25-5f60-490b-bf48-579517d1dea3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("218bad25-5f60-490b-bf48-579517d1dea3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '218bad25-5f60-490b-bf48-579517d1dea3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"abe7b805-9a08-4131-8380-753794117796":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"eb7dca7a-b58b-4e6c-bc7b-731237a80bd0","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a14a660b-31d1-44ba-902f-b5b97d1f95ed","type":"Rect"},{"attributes":{"data_source":{"id":"1392d574-a4db-4bb3-a5a5-5575e6b424bf","type":"ColumnDataSource"},"glyph":{"id":"9afcd156-d5ea-4e7b-bba9-8e722cab7358","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f1c6f299-a606-4e2b-ac33-a223fd5fa0dd","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"fa85c6a7-ec30-4871-a878-5b0522dd0e23","type":"ColumnDataSource"},"glyph":{"id":"b72ce535-6f81-46ed-8c0a-77a89a29578a","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7ab008ae-0d0d-49a9-ab64-a83d7c7713dd","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f62861e6-47fc-4d65-bd7b-4857172034b6","type":"PanTool"},{"id":"9abd0f0c-4549-4d56-9f12-3b11ea175ed3","type":"WheelZoomTool"},{"id":"d2fa8b06-83f8-479c-8816-b29233c67d59","type":"BoxZoomTool"},{"id":"542dfe98-28c0-498d-b6bb-2ae23106a4b0","type":"SaveTool"},{"id":"cc826fbc-6735-4490-9204-b432f20bf46c","type":"ResetTool"},{"id":"2cf3944a-2f8b-405e-bbe2-9d27d1572540","type":"HelpTool"}]},"id":"c45c3792-51a2-4341-b835-3774cf4de01e","type":"Toolbar"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"31f9339d-842f-4ff8-8d3e-627290807a96","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.3, 0.3]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[28.0],"label":["(0.3, 0.3]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03913043478260869],"x":["0.3"],"y":[14.0]}},"id":"1392d574-a4db-4bb3-a5a5-5575e6b424bf","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.4, 0.5]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[116.0],"label":["(0.4, 0.5]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03913043478260869],"x":["0.45"],"y":[58.0]}},"id":"4ea11595-2893-4cc6-beab-fdd6bd50c27d","type":"ColumnDataSource"},{"attributes":{"axis_label":"Count( Survival Rate Difference )","formatter":{"id":"fb6bd48c-e65b-421c-850e-c3aa0457e04c","type":"BasicTickFormatter"},"plot":{"id":"42ed067c-7df2-4c97-b0b3-38d97ed74f25","subtype":"Chart","type":"Plot"},"ticker":{"id":"f822a470-d7d8-4608-a8ba-7b1a23ffac95","type":"BasicTicker"}},"id":"2bb7ce56-576f-4df9-92a4-13b28f7ca806","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(1.0, 1.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(1.0, 1.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03913043478260869],"x":["1.0"],"y":[0.5]}},"id":"4766ca0d-6bdc-43ee-bdef-f2fd00eb2855","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.8, 0 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[15]</strong>&gt;</code></p>

# %%
print('The mean is %.2f and the standard deviation is %.2f.' %(survival_rate_difference.mean(),survival_rate_difference.std()))
# Out:
# The mean is 0.54 and the standard deviation is 0.13.

# %%
t_statistic = survival_rate_difference.mean()/(survival_rate_difference.std()/SIZE_SAMPLE**0.5)

print('The t-statistic is %.2f.' %t_statistic)
# Out:
# The t-statistic is 18.61.

# %% [markdown]
# The degree of freedom is 19.
#
# The t-critical is 1.729. (Remember we are only checking if it is higher, one direction.)

# %% [markdown]
# # Conclusion
# Since t-statistical is a lot higher than t-critical we can say that we drop the initial hypotesis and assume that the average survival rate for females is significant higher than the average survival rate for males.
#
# So answering the question in the begining of the statistical analysis: Does females had a higher chance of survival than males in the titanic?
#
# The answer is: Yes. We can say if 95% certainty that females had a higher chance of survival than males.
#
# It could be used to predict the chance of survival in the Titanic but we may have lurking features that are influencing on it also. So to verify how other features behave more studies should be done.
#
# Despite the simple conclusion, we know that the Titanic had 1300 passengers and our data base for the analysis only had 720. Depending of the data missing our analysis may need to be updated or totally discharged.
#
# Imagine that the missing data are from missing unidentified person and the majority are women, it can totally change the analysis.
