# %% [markdown]
# # P2 - Data Analyst
#
# ## Introduction
# The idea here is to explore the data and look for some conclusions we can get from the data. At this moment no question can be formulated without a first knowledge of the data

# %% [markdown]
# ## Importing
# Import libraries and CSV. Verify if CSV was imported correctly.

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from bokeh.plotting import figure
from bokeh.charts import Histogram
from bokeh.charts import Donut
from bokeh.charts import Bar
from bokeh.io import output_notebook, show
from bokeh.layouts import row
import random
from sets import Set

output_notebook()

df = pd.read_csv('titanic_data.csv')
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:14: DeprecationWarning: the sets module is deprecated
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3a8c2ac5-7640-4add-a6c0-7c9b520de133">Loading BokehJS ...</span>
#     </div>

# %%
df.describe()
# Out:
# C:\Anaconda2\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male   NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked
# 0        0         A/5 21171    7.2500          NaN        S
# 1        0          PC 17599   71.2833          C85        C
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 4        0            373450    8.0500          NaN        S
# 5        0            330877    8.4583          NaN        Q
# 6        0             17463   51.8625          E46        S
# 7        1            349909   21.0750          NaN        S
# 8        2            347742   11.1333          NaN        S
# 9        0            237736   30.0708          NaN        C
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 12       0         A/5. 2151    8.0500          NaN        S
# 13       5            347082   31.2750          NaN        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 16       1            382652   29.1250          NaN        Q
# 17       0            244373   13.0000          NaN        S
# 18       0            345763   18.0000          NaN        S
# 19       0              2649    7.2250          NaN        C
# 20       0            239865   26.0000          NaN        S
# 21       0            248698   13.0000          D56        S
# 22       0            330923    8.0292          NaN        Q
# 23       0            113788   35.5000           A6        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 26       0              2631    7.2250          NaN        C
# 27       2             19950  263.0000  C23 C25 C27        S
# 28       0            330959    7.8792          NaN        Q
# 29       0            349216    7.8958          NaN        S
# ..     ...               ...       ...          ...      ...
# 861      0             28134   11.5000          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 864      0            233866   13.0000          NaN        S
# 865      0            236852   13.0000          NaN        S
# 866      0     SC/PARIS 2149   13.8583          NaN        C
# 867      0          PC 17590   50.4958          A24        S
# 868      0            345777    9.5000          NaN        S
# 869      1            347742   11.1333          NaN        S
# 870      0            349248    7.8958          NaN        S
# 871      1             11751   52.5542          D35        S
# 872      0               695    5.0000  B51 B53 B55        S
# 873      0            345765    9.0000          NaN        S
# 874      0         P/PP 3381   24.0000          NaN        C
# 875      0              2667    7.2250          NaN        C
# 876      0              7534    9.8458          NaN        S
# 877      0            349212    7.8958          NaN        S
# 878      0            349217    7.8958          NaN        S
# 879      1             11767   83.1583          C50        C
# 880      1            230433   26.0000          NaN        S
# 881      0            349257    7.8958          NaN        S
# 882      0              7552   10.5167          NaN        S
# 883      0  C.A./SOTON 34068   10.5000          NaN        S
# 884      0   SOTON/OQ 392076    7.0500          NaN        S
# 885      5            382652   29.1250          NaN        Q
# 886      0            211536   13.0000          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
# 889      0            111369   30.0000         C148        C
# 890      0            370376    7.7500          NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Data Cleaning
# The 'Age' has some NaN and we must fix it.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# From a total of 891 passengers, we don't have the Age of 177, the Cabin of 687 and the Place of Embark for 2.
#
# We can consider that Cabin is nearly useless and remove this column.
#
# For the Place of Embark and Age, I will remove the passengers from our analysis. I am not happy by doing it, they are over 150 being removed but we will still keep over than 700 passengers to analyse

# %%
df_clean = df.copy()

del df_clean['Cabin']

df_clean = df_clean.dropna()

df_clean.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# The column PassengerId and Ticket will not give me any relevant statistical result, so they will be also removed.

# %%
del df_clean['PassengerId']
del df_clean['Ticket']

df_clean.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567251
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938648
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200

# %% [markdown]
# ## Exploring phase
# Now that the data is clean it is time to play with it. Let´s start with Age, we will verify if there is a major difference between the age of those who survived.

# %%
print("The total number of passengers were %d, from them only %d survived." 
      %(df_clean['Survived'].count(), df_clean[df_clean['Survived'] == 1]['Survived'].count()))
print("There is %d males and %d females in the cleaned data." 
      %(df_clean[df_clean['Sex'] == 'male']['Survived'].count(),
        df_clean[df_clean['Sex'] == 'female']['Survived'].count()))
# Out:
# The total number of passengers were 712, from them only 288 survived.
# There is 453 males and 259 females in the cleaned data.

# %% [markdown]
# Let´s check the Age, we will verify if there is a major difference between the age of those who survived.

# %%
hist = Histogram(df_clean, values='Age', title="Age of passagers Histogram", plot_width=400, plot_height=400)
hist2 = Histogram(df_clean, values='Age', color='Survived', legend='top_right',
                  title="Age of passagers Histogram if Survived or not", plot_width=400, plot_height=400)

show(row(hist,hist2))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="98f6363e-c0e3-46b9-8824-a722a6863362"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("98f6363e-c0e3-46b9-8824-a722a6863362");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '98f6363e-c0e3-46b9-8824-a722a6863362' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"65ddfdd2-13e8-489e-a479-dc77f28b7f65":{"roots":{"references":[{"attributes":{"data_source":{"id":"ba3fe7ea-7c9f-4af0-abfb-00fb9466070c","type":"ColumnDataSource"},"glyph":{"id":"1cfcc920-cf4b-45f2-b34a-b5fb2f0257dc","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"70a34ee4-52d7-4e8b-99f6-aef474384b64","type":"GlyphRenderer"},{"attributes":{"location":"top_left","plot":{"id":"223dd65f-83a4-41e8-994c-b0a71fbf0c3d","subtype":"Chart","type":"Plot"}},"id":"56855ad4-8a3b-4962-9dc6-9b0ec63ce886","type":"Legend"},{"attributes":{"axis_label":"Count( Age )","formatter":{"id":"080efa6d-a91b-4f99-8340-a1a8b3b9f612","type":"BasicTickFormatter"},"plot":{"id":"d440fe24-9e59-4dbd-935c-77eb6f8537a9","subtype":"Chart","type":"Plot"},"ticker":{"id":"f6dd82ee-ee0e-4d19-a80d-2121d83d7d7b","type":"BasicTicker"}},"id":"f9e12d9a-7603-432b-af88-da6c018fdefb","type":"LinearAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d27ff757-eb88-4cb4-9de3-6cd0f056cf66","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a77295d-2ebc-4b75-a63b-d0fc60361294","type":"Rect"},{"attributes":{"data_source":{"id":"0b16acb7-f327-4625-8515-d65fae0ba49a","type":"ColumnDataSource"},"glyph":{"id":"c8d15753-de21-4fc3-bb35-a03272687052","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"50603a84-1b32-4477-bccd-01c0e3cb3828","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(10.1, 14.7]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[7.0],"label":["(10.1, 14.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.5625],"x":["12.4"],"y":[3.5]}},"id":"eaefc0f8-2210-44cd-af53-0c3c2246a7af","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f5ffa95a-e10b-4e1b-b3fc-dd231c3f94a5","type":"Rect"},{"attributes":{},"id":"f6dd82ee-ee0e-4d19-a80d-2121d83d7d7b","type":"BasicTicker"},{"attributes":{"data_source":{"id":"cca702f4-739c-4781-a14e-e497b7d95944","type":"ColumnDataSource"},"glyph":{"id":"ab45660d-69e8-40d9-8552-ec1a037fec9d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"694adc9e-37e6-486e-b496-215d01840e1a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"fd89f44f-4e3f-41ca-be55-71000670734f","type":"ColumnDataSource"},"glyph":{"id":"3a35a3e4-3705-4b78-bcb3-42309a16d922","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6933f91a-26db-4498-b639-de6e1a57276e","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":81.996875,"start":-1.5968749999999994},"id":"0ed1afe6-6884-40e9-92a3-5b59f67b0ba4","type":"Range1d"},{"attributes":{"data_source":{"id":"8d1161ce-aea6-4fed-9426-16c8aef79230","type":"ColumnDataSource"},"glyph":{"id":"afb1ef35-8c90-405b-91de-96a034ef6e69","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0e5c4a23-b631-4747-bac4-f26965a4c108","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(36.2, 40.2]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[44.0],"label":["(36.2, 40.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[3.978999999999999],"x":[ ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %% [markdown]
# It surprised me that most of the babies (below 5) survived and someone above 75. But it is not much to play with it.
#
# Let's check if there is a difference for 'Sex'.

# %%
df_female = df_clean[df_clean['Sex'] == 'female']
df_male = df_clean[df_clean['Sex'] == 'male']

female_survived = df_female[df_female['Survived'] == 1].loc[:,'Survived'].count()
female_not_survived = df_female[df_female['Survived'] == 0].loc[:,'Survived'].count()
male_survived = df_male[df_male['Survived'] == 1].loc[:,'Survived'].count()
male_not_survived = df_male[df_male['Survived'] == 0].loc[:,'Survived'].count()

df_simple = pd.DataFrame({'Sex': ['female', 'female', 'male', 'male'], 
             'Survived': ['Survived', 'Not survived', 'Survived', 'Not survived'], 
             'counting': [female_survived, female_not_survived, male_survived, male_not_survived]})

bar = Bar(df_simple, values='counting', label='Survived', stack='Sex', legend='top_center',
                  title="Age of passagers Histogram if Survived or not", plot_width=400, plot_height=400)
hist = Histogram(df_clean, values='Age', color='Sex', legend='top_right',
                  title="Age of passagers Histogram if Survived or not", plot_width=400, plot_height=400)

show(row(bar,hist))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="81f963d4-240d-42b4-96ee-a41fd03d8668"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("81f963d4-240d-42b4-96ee-a41fd03d8668");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '81f963d4-240d-42b4-96ee-a41fd03d8668' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3052d475-07c0-4333-aef7-f758f8cceb8b":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b85d3376-e54e-4a4b-992b-fa9fa0d4267e","type":"Rect"},{"attributes":{"data_source":{"id":"3fcd6149-f7e7-418f-92d0-be7236557f10","type":"ColumnDataSource"},"glyph":{"id":"b1ddd228-6faa-4541-b817-6ad77fdf5225","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e339ba44-8d62-401c-95a1-2369691374c7","type":"GlyphRenderer"},{"attributes":{"axis_label":"Sum( Counting )","formatter":{"id":"a694f4f8-6327-4e66-897c-23906eff3988","type":"BasicTickFormatter"},"plot":{"id":"96c693ef-d2f7-4768-98ea-12271bc02ae9","subtype":"Chart","type":"Plot"},"ticker":{"id":"3940d7c3-5ce1-4f05-841c-dfd4944a5867","type":"BasicTicker"}},"id":"0da4d764-9871-475a-b57e-2d4a13e84344","type":"LinearAxis"},{"attributes":{"plot":{"id":"96c693ef-d2f7-4768-98ea-12271bc02ae9","subtype":"Chart","type":"Plot"}},"id":"d196eac8-f444-4faa-af6e-032bdf63a8ec","type":"SaveTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"aac62784-7619-4973-b5d0-eb7a58b5ce19","type":"Rect"},{"attributes":{"data_source":{"id":"34b1b018-3e66-4446-8bb0-2cd4426ef41b","type":"ColumnDataSource"},"glyph":{"id":"018ffc42-951a-453a-8775-1fd0439c1e35","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d78898b8-ac48-447f-8e2a-16f019299d3a","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"41ea1f45-2dd6-418e-8246-461e84fa035a","type":"BoxAnnotation"},"plot":{"id":"cec4c87b-91d7-45ed-8580-1a33f112276d","subtype":"Chart","type":"Plot"}},"id":"2c9ea718-f6f8-4a59-a744-77f533d3435a","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(66.0, 70.6]"],"color":["#5ab738"],"fill_alpha":[0.6],"height":[4.0],"label":["(66.0, 70.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[4.681176470588227],"x":["68.3"],"y":[2.0]}},"id":"c7f8e184-572b-4bd3-9b62-77b52da845a5","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"899d2fb9-72ef-42fc-81d6-34ee9afd2c3c","type":"ColumnDataSource"},"glyph":{"id":"2064761b-474c-4ef9-8604-5e7a538c9b63","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8132e908-f42e-48e4-ba73-2ff61552eb49","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"8b985aa2-8cab-407a-83d6-a4c3e36bb60b","type":"ColumnDataSource"},"glyph":{"id":"7e510eb9-f25a-4237-8099-885c0abe8a76","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0b96223d-7521-4573-8acb-4b732cfc7c60","type":"GlyphRenderer"},{"attributes":{"axis_label":"Count( Age )","formatter":{"id":"372cde5a-3caf-4541-adb1-f356f81cca78","type":"BasicTickFormatter"},"plot":{"id":"cec4c87b-91d7-45ed-8580-1a33f112276d","subtype":"Chart","type":"Plot"},"ticker":{"id":"d89f299a-b421-4fa9-a4e0-8081c5fe8a3f","type":"BasicTicker"}},"id":"8ecaeffd-099c-4cc4-aa1d-04ca9b996617","type":"LinearAxis"},{"attributes":{"axis_label":"Age","formatter":{"id":"f75aac1b-f76d-493d-8be3-9fc2bcca913e","type":"BasicTickFormatter"},"plot":{"id":"cec4c87b-91d7-45ed-8580-1a33f112276d","subtype":"Chart","type":"Plot"},"ticker":{"id":"a6d3ebe0-2e9f-42ec-9dea-ba5558a85f51","type":"BasicTicker"}},"id":"777feeb2-926d-4bf4-b77b-81deb4a18d0d","type":"LinearAxis"},{"attributes":{"data_source":{"id":"e54dd10e-ff2e-4e46-9372-f6c2aff419dc","type":"ColumnDataSource"},"glyph":{"id":"d274167a-8570-42ba-8775-224c0725acf3","type":"Rect"},"hover_glyph":null,"nonselection_gl ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %% [markdown]
# Now it really surprised me. The amount of females that survived is a lot bigger them the mount of males.
#
# The age between males and females didn't change a lot. Since we checked something more interesting in the survival, let's play with it.
#
# To improve the understanding let's check one more graphic about the Sex and Survival.

# %%
d = Donut(df_simple, label=['Sex','Survived'], values='counting')

show(d)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="5771b9bc-49a8-49b6-b1e4-b21dc2a4db95"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5771b9bc-49a8-49b6-b1e4-b21dc2a4db95");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5771b9bc-49a8-49b6-b1e4-b21dc2a4db95' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"87589f16-e2de-4e23-9281-36b31fcd8bc6":{"roots":{"references":[{"attributes":{"angle":{"field":"text_angle","units":"rad"},"text_align":"center","text_baseline":"middle","text_font_size":{"value":"10pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"06561ea5-83de-4139-a1e6-7ccedf8e6731","type":"Text"},{"attributes":{"axis_label":null,"formatter":{"id":"2ed57279-2c79-4036-9b0d-c6c9211f8a83","type":"BasicTickFormatter"},"plot":{"id":"94f8172d-e7e8-4fb5-a80f-d30d7800a319","subtype":"Chart","type":"Plot"},"ticker":{"id":"4b3ce2c2-7929-44c4-91e6-7d651b7f4915","type":"BasicTicker"},"visible":false},"id":"9f464f2e-9a15-4510-aa46-10571e5d19b5","type":"LinearAxis"},{"attributes":{"plot":{"id":"94f8172d-e7e8-4fb5-a80f-d30d7800a319","subtype":"Chart","type":"Plot"}},"id":"2f912d45-cd6e-4760-a1c7-8e58c7343088","type":"WheelZoomTool"},{"attributes":{"end_angle":{"field":"end","units":"rad"},"fill_alpha":{"value":0.8},"fill_color":{"field":"color"},"inner_radius":{"field":"inners","units":"data"},"line_color":{"value":"White"},"outer_radius":{"field":"outers","units":"data"},"start_angle":{"field":"start","units":"rad"},"x":{"value":0},"y":{"value":0}},"id":"cd8bc05e-8801-4b7a-9178-012431f5610b","type":"AnnularWedge"},{"attributes":{},"id":"2ed57279-2c79-4036-9b0d-c6c9211f8a83","type":"BasicTickFormatter"},{"attributes":{"location":"top_left","plot":{"id":"94f8172d-e7e8-4fb5-a80f-d30d7800a319","subtype":"Chart","type":"Plot"}},"id":"1f6905f5-66b1-4023-b466-fe601d066d3d","type":"Legend"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4634d29b-9592-4fc6-861c-1e120189e3f0","type":"PanTool"},{"id":"2f912d45-cd6e-4760-a1c7-8e58c7343088","type":"WheelZoomTool"},{"id":"5662b8b8-9a33-4af7-8acf-c93a182479c6","type":"BoxZoomTool"},{"id":"9e198073-5a4b-4139-9386-e356e608c635","type":"SaveTool"},{"id":"95e8e37d-42d7-40bf-bf15-7bcb73dd6004","type":"ResetTool"},{"id":"0798b856-b672-4d05-8228-64a1918d3b8f","type":"HelpTool"}]},"id":"4f15b207-403b-4b36-a8a0-b8d21004a71c","type":"Toolbar"},{"attributes":{"plot":{"id":"94f8172d-e7e8-4fb5-a80f-d30d7800a319","subtype":"Chart","type":"Plot"}},"id":"95e8e37d-42d7-40bf-bf15-7bcb73dd6004","type":"ResetTool"},{"attributes":{"plot":null,"text":null},"id":"3c0a36b3-3df3-46d5-ae24-eed8c3b908ad","type":"Title"},{"attributes":{"axis_label":null,"formatter":{"id":"cb84deee-e194-4f99-9e82-1123c04af4a3","type":"BasicTickFormatter"},"plot":{"id":"94f8172d-e7e8-4fb5-a80f-d30d7800a319","subtype":"Chart","type":"Plot"},"ticker":{"id":"6cc0dc66-d872-40ad-b05e-1b2391938092","type":"BasicTicker"},"visible":false},"id":"c62efb0d-9cac-4cc9-b3d5-c5ef274618a9","type":"LinearAxis"},{"attributes":{"overlay":{"id":"9ce82565-4851-41da-95b7-e1c0bd038e97","type":"BoxAnnotation"},"plot":{"id":"94f8172d-e7e8-4fb5-a80f-d30d7800a319","subtype":"Chart","type":"Plot"}},"id":"5662b8b8-9a33-4af7-8acf-c93a182479c6","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"94f8172d-e7e8-4fb5-a80f-d30d7800a319","subtype":"Chart","type":"Plot"}},"id":"0798b856-b672-4d05-8228-64a1918d3b8f","type":"HelpTool"},{"attributes":{"plot":{"id":"94f8172d-e7e8-4fb5-a80f-d30d7800a319","subtype":"Chart","type":"Plot"}},"id":"9e198073-5a4b-4139-9386-e356e608c635","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9ce82565-4851-41da-95b7-e1c0bd038e97","type":"BoxAnnotation"},{"attributes":{},"id":"934a8bf1-597f-46ed-a180-8ced9656088d","type":"ToolEvents"},{"attributes":{"below":[{"id":"9f464f2e-9a15-4510-aa46-10571e5d19b5","type":"LinearAxis"}],"left":[{"id":"c62efb0d-9cac-4cc9-b3d5-c5ef274618a9","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"9ce82565-4851-41da-95b7-e1c0bd038e97","ty ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[10]</strong>&gt;</code></p>

# %% [markdown]
# Again we can clearly see that females survived a lot more than man.

# %%
def survival_rate(sex):
    df_one_sex = df_clean[df_clean['Sex'] == sex]
    count_survivals = df_one_sex[df_one_sex['Survived'] == 1].loc[:,'Survived'].count()
    count_one_sex = df_one_sex['Survived'].count()
    return float(count_survivals)/count_one_sex

survival_rate_male = survival_rate('male')
survival_rate_female = survival_rate('female')

print("The survival rate for males were %.2f and for females were %.2f." %(survival_rate_male, survival_rate_female))
# Out:
# The survival rate for males were 0.21 and for females were 0.75.

# %% [markdown]
# I am suprised again, I didn't expect that much difference in the percentages. I will try to statistically indicate that the survival rate for the females in the titanic were higher than the males.

# %% [markdown]
# # Statistical analysis
# Now that the data is already known we will try to draw some conclusions. Here the question is: Does females had a higher chance of survival than males in the titanic?
#
# Here will we try to show the statistical significance that the average survival rate for the females in the titanic were higher than the survival rate for the males.
#
# We will draw 1000 random samples of 20 subjects for each, show the histogram of the survival rate for the samples and check if the average survival rate for females is significant higher than for the males.
#
# We will use the critical value of 0.05 and we will use the t-test.
#
# So Hypotesis 0:
# average survival rate of females <= average survival rate of males
#
# Alternative Hypotesis:
# average survival rate of females > average survival rate of males

# %%
SIZE_SAMPLE = 20
TOTAL_SIZE = 1000

def sample(sex,size_sample):
    indexes = Set([])
    while len(indexes) < size_sample:
        df_one_sex = df_clean[df_clean['Sex'] == sex]
        indexes.add(random.choice(df_one_sex.index))
    return indexes

def survival_rate_of_sample(indexes):
    survivals = []
    for index in indexes:
        survivals.append(df_clean.loc[index,'Survived'])
    return float(sum(survivals))/len(survivals)

def survival_rate_list(sex,total_size,size_sample):
    samples_surv_rate = []
    for num_sample in range(total_size):
        samples_surv_rate.append(survival_rate_of_sample(sample(sex,size_sample)))
    return samples_surv_rate
    

survival_rate_list_male = survival_rate_list('male',TOTAL_SIZE,SIZE_SAMPLE)
survival_rate_list_female = survival_rate_list('female',TOTAL_SIZE,SIZE_SAMPLE)

# %% [markdown]
# Note: there is a chance of keeping twice the same survival rate (if the 20 samples are the same). Since the chance is extremely small we are ignoring it.

# %%
data = pd.DataFrame({'Sex': [], 'survival_rate': []})

for survival_rate_male in survival_rate_list_male:
    data = data.append({'Sex': 'male', 'survival_rate': survival_rate_male},ignore_index=True)
for survival_rate_female in survival_rate_list_female:
    data = data.append({'Sex': 'female', 'survival_rate': survival_rate_female},ignore_index=True)

# %%
hist = Histogram(data, values='survival_rate', color='Sex', title="Survival rate for sex Histogram",
                 plot_width=400, plot_height=400, legend='top_center')

show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0a0616a1-5a73-4faf-af13-09e38a021a68"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0a0616a1-5a73-4faf-af13-09e38a021a68");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0a0616a1-5a73-4faf-af13-09e38a021a68' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"38d217ad-ce85-464b-9ecb-8800dff30349":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0b373446-fb07-47bc-80bf-76dbcff8b0e2","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"138e857c-9234-40cf-89e0-7ecf5b1b33ec","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e1e696b2-2a17-463f-8cbb-c5541057c5c5","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.6, 0.6]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.6, 0.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.020000000000000018],"x":["0.6"],"y":[0.0]}},"id":"a6ec8130-f25d-4d8a-990c-290fb70d2813","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b55de183-3a32-4afe-926b-4ba3c518c8c7","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.4, 0.4]"],"color":["#f22c40"],"fill_alpha":[0.6],"height":[0.0],"label":["(0.4, 0.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.019999999999999962],"x":["0.4"],"y":[0.0]}},"id":"5ae49530-07e8-4fc0-8ad4-4018f665f7fc","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a6ec8130-f25d-4d8a-990c-290fb70d2813","type":"ColumnDataSource"},"glyph":{"id":"ac6c3c96-9151-43cf-aa74-3587bc803933","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6553f197-12a1-467c-99e0-67c73779b918","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"5a036b6e-c3e7-4c90-9b2a-fb29b98eb945","type":"ColumnDataSource"},"glyph":{"id":"274a5f8b-f84d-475c-92f6-4f61cd3f8c7d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fce4c7a8-5fbb-4a7a-859b-5ca595cc9f98","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"0067cc65-b1aa-4dfa-bb5f-58a9b9d99480","type":"ColumnDataSource"},"glyph":{"id":"68810944-86a4-4fa2-8bf0-bfa1ab6f7d96","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7ba4b227-bfd8-4587-ab27-f94e6438915e","type":"GlyphRenderer"},{"attributes":{},"id":"510e8ce4-c0b2-482d-bc28-43aa5cbd9220","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"3c242dbc-27da-4b74-882e-4cc3ec3d43ef","type":"BoxAnnotation"},"plot":{"id":"d7a81cea-8074-4591-a212-d17e3af4787b","subtype":"Chart","type":"Plot"}},"id":"5e37075d-a6dd-4124-a62f-8f7947ffc616","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"a2352b55-c72f-49a8-9a45-6e05a73013da","type":"ColumnDataSource"},"glyph":{"id":"ad0dc192-d42a-411f-9816-a686b27c82fd","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e2e895a4-0ed2-4664-bbc4-989f65f6f493","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"12310baf-496a-4250-8923-a9dfa5fe9e6f","type":"ColumnDataSource"},"glyph":{"id":"138e857c-9234-40cf-89e0-7ecf5b1b33ec","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7fd94695-6600-46a9-a4c1-fff8b75f1e4d","type":"GlyphRenderer"},{"attributes":{"callback":null ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %% [markdown]
# We want to check the difference so we will analyse the female survival rate - male survival rate

# %%
survival_rate_difference = np.array(survival_rate_list_female) - np.array(survival_rate_list_male)

hist = Histogram(pd.DataFrame({'Survival rate difference': survival_rate_difference}),
                 title="Survival rate difference Histogram", plot_width=400, plot_height=400)

show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="4df03701-658b-4872-a876-7b39d4872d1f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4df03701-658b-4872-a876-7b39d4872d1f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4df03701-658b-4872-a876-7b39d4872d1f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6bb693ee-ec53-43e1-9cb1-fadd3e9b31a5":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c488c7ff-ce73-432b-8f55-4ae55d0e5db6","type":"PanTool"},{"id":"6dafed3b-9968-4eea-9c0e-e9360b8129d7","type":"WheelZoomTool"},{"id":"5ca7aa09-db64-4e36-9c0d-9f3c6a954db3","type":"BoxZoomTool"},{"id":"7133f96f-d745-4b18-88de-71e71f499c92","type":"SaveTool"},{"id":"d0139d76-2348-4ef7-ad2b-41ddfceed08d","type":"ResetTool"},{"id":"4d1a2802-37b2-457c-b89b-a3c0ff6a1575","type":"HelpTool"}]},"id":"813acfcf-613c-4356-8c02-0478fa392443","type":"Toolbar"},{"attributes":{"data_source":{"id":"bdf05f8a-e369-4d0f-871b-9eb78381040d","type":"ColumnDataSource"},"glyph":{"id":"7cdb62d1-9065-4f1d-afb8-169ca8060061","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"92e818d3-a5ad-4701-8637-63cfafd3a1a3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1b258095-d7c2-43b3-86ca-f233f0cd1547","type":"Rect"},{"attributes":{},"id":"e1654c8e-9c71-4f09-8994-9b44e290cd45","type":"BasicTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"901f0f44-7c92-43ac-92b4-46d3e71c2ca2","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6ecd734d-07d8-42cf-8025-3ed1a77ab1ae","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"472d5e14-c6ec-4fd8-89af-5a2e3852218d","type":"Rect"},{"attributes":{"callback":null,"end":179.3},"id":"6bb20fa6-6402-470f-9c4a-67627d5d1e15","type":"Range1d"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.2, 0.2]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(0.2, 0.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.0380952380952381],"x":["0.2"],"y":[2.0]}},"id":"82a46950-5c98-4df8-be2d-ed0a2d31f4a7","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"2857e684-a0c5-4058-b4a7-5225f8d08fc4","subtype":"Chart","type":"Plot"}},"id":"7133f96f-d745-4b18-88de-71e71f499c92","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":["(0.5, 0.6]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[163.0],"label":["(0.5, 0.6]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.03809523809523796],"x":["0.55"],"y":[81.5]}},"id":"c43632dc-cf71-4bca-b275-b04689039deb","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9bc6ba67-db1c-4f45-8d6f-36bf9ed90803","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4ad22983-c8d5-4496-a564-1c26b3076f50","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","h ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[15]</strong>&gt;</code></p>

# %%
print('The mean is %.2f and the standard deviation is %.2f.' %(survival_rate_difference.mean(),survival_rate_difference.std()))
# Out:
# The mean is 0.55 and the standard deviation is 0.13.

# %%
t_statistic = survival_rate_difference.mean()/(survival_rate_difference.std()/SIZE_SAMPLE**0.5)

print('The t-statistic is %.2f.' %t_statistic)
# Out:
# The t-statistic is 19.55.

# %% [markdown]
# The degree of freedom is 19.
#
# The t-critical is 1.729. (Remember we are only checking if it is higher, one direction.)

# %% [markdown]
# # Conclusion
# Since t-statistical is a lot higher than t-critical we can say that we drop the initial hypotesis and assume that the average survival rate for females is significant higher than the average survival rate for males.
#
# So answering the question in the begining of the statistical analysis: Does females had a higher chance of survival than males in the titanic?
#
# The answer is: Yes. We can say if 95% certainty that females had a higher chance of survival than males.
#
# It could be used to predict the chance of survival in the Titanic but we may have lurking features that are influencing on it also. So to verify how other features behave more studies should be done.
#
# Despite the simple conclusion, we know that the Titanic had 1300 passengers and our data base for the analysis only had 720. Depending of the data missing our analysis may need to be updated or totally discharged.
#
# Imagine that the missing data are from missing unidentified person and the majority are women, it can totally change the analysis.
